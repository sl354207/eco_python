# %%
import pandas as pd
import numpy as np

pd.set_option("display.max_columns", None)
# pd.set_option('display.max_rows', 100)
# pd.set_option('display.max_seq_items', 100)

# 400 meter coordinate accuracy
# 1923 earliest year

# %%
# read in cleaned andmerged data
df_path = input("Enter the file path: ")

df = pd.read_parquet(df_path)

# %%
df

# %%
kingdoms = df["kingdom"].unique()

# %%
fungi = df[(df["kingdom"] == "Fungi")]

chromista = df[(df["kingdom"] == "Chromista")]

bacteria = df[(df["kingdom"] == "Bacteria")]

protozoa = df[(df["kingdom"] == "Protozoa")]

virus = df[(df["kingdom"] == "Viruses")]

animal = df[(df["kingdom"] == "Animalia")]

plant = df[(df["kingdom"] == "Plantae")]

archaea = df[(df["kingdom"] == "Archaea")]

# %%
na_kingdom = df[(df["kingdom"].isna())]
na_phylum = df[(df["phylum"].isna())]
na_class = df[(df["class"].isna())]
na_order = df[(df["order"].isna())]
na_family = df[(df["family"].isna())]
na_genus = df[(df["genus"].isna())]

# %%
species_type = df[(df["species_type"].notna())]

# %%
species_type_unique = df["species_type"].unique()

# %%
na_plant = plant[(plant["species_type"].isna())]

na_animal = animal[(animal["species_type"].isna())]

na_fungi = fungi[(fungi["species_type"].isna())]

na_chromista = chromista[(chromista["species_type"].isna())]

na_bacteria = bacteria[(bacteria["species_type"].isna())]

na_protozoa = protozoa[(protozoa["species_type"].isna())]

na_virus = virus[(virus["species_type"].isna())]

na_archaea = archaea[(archaea["species_type"].isna())]

na_species_type = df[(df["species_type"].isna())]

# %%
species_unique = df["scientific_name"].unique()

# %%
# convert family column to lowercase except for first letter
df["family"] = df["family"].str.capitalize()

# %%
# check for strange x at beginning of df names and remove if necessary

df = df[~df.scientific_name.isin(["spec."])]

# %%
species_values = np.array([len(word.split()) for word in species_unique])

max_value = np.max(species_values)
min_value = np.min(species_values)

# %%
species_2 = []
for i in range(len(species_values)):
    if species_values[i] < 2:
        species_2.append(species_unique[i])

# %%
# remove the rows in df that contain the values in df_2
df = df[~df.scientific_name.isin(species_2)]

# %%
# find values in scientific_name column that contain special characters and remove them

df = df[
    ~df.scientific_name.str.contains(
        "[^a-zA-Z-\s]",
    )
]

# %%
# make genus column equal first word in scientific_name column

df["genus"] = df["scientific_name"].str.split().str[0]

# %%
na_genus = df[(df["genus"].isna())]

# %%
phylum_unique = df["phylum"].unique()

# %%
df = df[
    ~df.phylum.isin(
        [
            "Firmicutes_A",
            "Firmicutes_B",
            "Desulfobacterota_I",
            "Nitrospirota_A",
            "Bacteria incertae sedis",
        ]
    )
]

# %%
class_unique = df["class"].unique()

# %%
df = df[
    ~df["class"].isin(
        [
            "Cryptophyta incertae sedis",
            "Haptophyta incertae sedis",
            "Mortierellomycotina incertae sedis",
            "Nematoda incertae sedis",
            "Khakista incertae sedis",
            "Chlorophyta incertae sedis",
            "Dinoflagellata incertae sedis",
            "Rhodophyta incertae sedis",
            "Pezizomycotina incertae sedis",
        ]
    )
]

# %%
order_unique = df["order"].unique()

# %%
# drop na values from order_unique nd array

order_unique = np.array([word for word in order_unique if word != None])

# %%
order_values = np.array([len(word.split()) for word in order_unique])

max_value = np.max(order_values)
min_value = np.min(order_values)

# %%
order_2 = []
for i in range(len(order_values)):
    if order_values[i] > 1:
        order_2.append(order_unique[i])

# %%
df = df[~df.order.isin(order_2)]

# %%
family_unique = df["family"].unique()

family_unique = np.array([word for word in family_unique if word != None])

# %%
family_values = np.array([len(word.split()) for word in family_unique])

max_value = np.max(family_values)
min_value = np.min(family_values)

# %%
family_2 = []
for i in range(len(family_values)):
    if family_values[i] > 1:
        family_2.append(family_unique[i])

# %%
df = df[~df.family.isin(family_2)]

# %%
genus_unique = df["genus"].unique()

genus_unique = np.array([word for word in genus_unique if word != None])

# %%
genus_values = np.array([len(word.split()) for word in genus_unique])

max_value = np.max(genus_values)
min_value = np.min(genus_values)

# %%
df = df[~df.scientific_name.isin(
    ["Labyrinthulochytrium arktikum", "Lagrioda brounii"])]

# %%
del (
    order_2,
    family_2,
    max_value,
    min_value,
    family_values,
    order_values,
    genus_values,
    i,
    species_2,
    species_values,
)

# %%
na_family["genus"].value_counts().head(20)

# %%
# del Ancyluris
# Ancyluris = df[(df["genus"] == "Ancyluris")]

# %%
# del mesosemia
df.loc[df["genus"] == "Mesosemia", "family"] = "Riodinidae"
df.loc[df["genus"] == "Calephelis", "family"] = "Riodinidae"
df.loc[df["genus"] == "Nymphidium", "family"] = "Riodinidae"
df.loc[df["genus"] == "Symmachia", "family"] = "Riodinidae"
df.loc[df["genus"] == "Anteros", "family"] = "Riodinidae"
df.loc[df["genus"] == "Calydna", "family"] = "Riodinidae"
df.loc[df["genus"] == "Baeotis", "family"] = "Riodinidae"
df.loc[df["genus"] == "Ancyluris", "family"] = "Riodinidae"
df.loc[df["genus"] == "Charis", "family"] = "Riodinidae"
df.loc[df["genus"] == "Sarota", "family"] = "Riodinidae"
df.loc[df["genus"] == "Hyphilaria", "family"] = "Riodinidae"
df.loc[df["genus"] == "Alesa", "family"] = "Riodinidae"
df.loc[df["genus"] == "Setabis", "family"] = "Riodinidae"

# %%
df.loc[df["genus"] == "Endococcus", "family"] = "Lichenotheliaceae"

# %%
df.loc[df["genus"] == "Malaveria", "family"] = "Nymphalidae"
df.loc[df["genus"] == "Scriptor", "family"] = "Nymphalidae"

# %%
df.loc[df["genus"] == "Osteocephalus", "family"] = "Hylidae"

# %%
df.loc[df["genus"] == "Pilophoropsidea", "family"] = "Miridae"

# %%
df.loc[df["genus"] == "Zeugodacus", "family"] = "Tephritidae"

# %%
df.loc[df["genus"] == "Pholis", "family"] = "Pholidae"

# %%
df.loc[df["genus"] == "Vauricia", "family"] = "Curculionidae"

# %%
df.loc[df["genus"] == "Brailovskylus", "family"] = "Scutelleridae"

# %%
df.loc[df["genus"] == "Paragylla", "family"] = "Reduviidae"

# %%
df.loc[df["genus"] == "Tropidoatractus", "family"] = "Tropidoatractidae"

# %%
# baeotis = df[(df["genus"] == "Baeotis")]

# %%
na_order["family"].value_counts().head(60)

# %%
# del Orchidaceae
# Orchidaceae = df[(df["family"] == "Orchidaceae")]

# %%
df.loc[df["family"] == "Colubridae", "order"] = "Squamata"
df.loc[df["family"] == "Scincidae", "order"] = "Squamata"
df.loc[df["family"] == "Gekkonidae", "order"] = "Squamata"

# %%
df.loc[df["class"] == "Squamata", "order"] = "Squamata"
df.loc[df["order"] == "Squamata", "class"] = "Reptilia"

# %%
df.loc[df["family"] == "Asteraceae", "order"] = "Asterales"

# %%
df.loc[df["family"] == "Fabaceae", "order"] = "Fabales"

# %%
df.loc[df["family"] == "Scrophulariaceae", "order"] = "Lamiales"
df.loc[df["family"] == "Lamiaceae", "order"] = "Lamiales"

# %%
df.loc[df["family"] == "Rosaceae", "order"] = "Rosales"

# %%
df.loc[df["family"] == "Poaceae", "order"] = "Poales"
df.loc[df["family"] == "Cyperaceae", "order"] = "Poales"

# %%
df.loc[df["family"] == "Riodinidae", "order"] = "Lepidoptera"
df.loc[df["family"] == "Nymphalidae", "order"] = "Lepidoptera"

# %%
df.loc[df["family"] == "Onagraceae", "order"] = "Myrtales"

# %%
df.loc[df["family"] == "Brassicaceae", "order"] = "Brassicales"

# %%
df.loc[df["family"] == "Polygonaceae", "order"] = "Caryophyllales"
df.loc[df["family"] == "Caryophyllaceae", "order"] = "Caryophyllales"
df.loc[df["family"] == "Cactaceae", "order"] = "Caryophyllales"
df.loc[df["family"] == "Chenopodiaceae", "order"] = "Caryophyllales"

# %%
df.loc[df["family"] == "Boraginaceae", "order"] = "Boraginales"

# %%
df.loc[df["family"] == "Ericaceae", "order"] = "Ericales"
df.loc[df["family"] == "Primulaceae", "order"] = "Ericales"
df.loc[df["family"] == "Polemoniaceae", "order"] = "Ericales"

# %%
df.loc[df["family"] == "Spionidae", "order"] = "Spionida"

# %%
df.loc[df["family"] == "Pseudocerotidae", "order"] = "Polycladida"

# %%
df.loc[df["family"] == "Cirratulidae", "order"] = "Terebellida"
df.loc[df["family"] == "Flabelligeridae", "order"] = "Terebellida"

# %%
df.loc[df["family"] == "Ranunculaceae", "order"] = "Ranunculales"

# %%
df.loc[df["family"] == "Apiaceae", "order"] = "Apiales"

# %%
df.loc[df["family"] == "Peripatopsidae", "order"] = "Euonycophora"

# %%
df.loc[df["family"] == "Cerianthidae", "order"] = "Spirularia"

# %%
df.loc[df["family"] == "Hyphodiscaceae", "order"] = "Helotiales"

# %%
df.loc[df["family"] == "Chaetonotidae", "order"] = "Chaetonotida"

# %%
df.loc[df["family"] == "Euphorbiaceae", "order"] = "Malpighiales"

# %%
df.loc[df["family"] == "Testudinidae", "order"] = "Testudines"

# %%
df.loc[df["class"] == "Testudines", "order"] = "Testudines"
df.loc[df["order"] == "Testudines", "class"] = "Reptilia"

# %%
df.loc[df["family"] == "Saxifragaceae", "order"] = "Saxifragales"

# %%
df.loc[df["family"] == "Orchidaceae", "order"] = "Asparagales"

# %%
df.loc[df["family"] == "Hylidae", "order"] = "Anura"

# %%
df.loc[df["family"] == "Miridae", "order"] = "Hemiptera"
df.loc[df["family"] == "Scutelleridae", "order"] = "Hemiptera"

# %%
df.loc[df["family"] == "Tephritidae", "order"] = "Diptera"

# %%
df.loc[df["family"] == "Pholidae", "order"] = "Perciformes"

# %%
df.loc[df["family"] == "Curculionidae", "order"] = "Coleoptera"

# %%
df.loc[df["family"] == "Tropidoatractidae", "order"] = "Armophorida"

# %%
na_class["order"].value_counts().head(40)

# %%
# del Myctophiformes
# Myctophiformes = df[(df["order"] == "Myctophiformes")]

# %%
# Asparagales['class'].value_counts()

# %%
df.loc[df["order"] == "Perciformes", "class"] = "Actinopterygii"
df.loc[df["order"] == "Cypriniformes", "class"] = "Actinopterygii"
df.loc[df["order"] == "Siluriformes", "class"] = "Actinopterygii"
df.loc[df["order"] == "Characiformes", "class"] = "Actinopterygii"
df.loc[df["order"] == "Scorpaeniformes", "class"] = "Actinopterygii"
df.loc[df["order"] == "Cyprinodontiformes", "class"] = "Actinopterygii"
df.loc[df["order"] == "Anguilliformes", "class"] = "Actinopterygii"
df.loc[df["order"] == "Pleuronectiformes", "class"] = "Actinopterygii"
df.loc[df["order"] == "Clupeiformes", "class"] = "Actinopterygii"
df.loc[df["order"] == "Syngnathiformes", "class"] = "Actinopterygii"
df.loc[df["order"] == "Beloniformes", "class"] = "Actinopterygii"
df.loc[df["order"] == "Tetraodontiformes", "class"] = "Actinopterygii"
df.loc[df["order"] == "Atheriniformes", "class"] = "Actinopterygii"
df.loc[df["order"] == "Ophidiiformes", "class"] = "Actinopterygii"
df.loc[df["order"] == "Osmeriformes", "class"] = "Actinopterygii"
df.loc[df["order"] == "Osteoglossiformes", "class"] = "Actinopterygii"
df.loc[df["order"] == "Salmoniformes", "class"] = "Actinopterygii"
df.loc[df["order"] == "Aulopiformes", "class"] = "Actinopterygii"
df.loc[df["order"] == "Synbranchiformes", "class"] = "Actinopterygii"
df.loc[df["order"] == "Lophiiformes", "class"] = "Actinopterygii"
df.loc[df["order"] == "Batrachoidiformes", "class"] = "Actinopterygii"
df.loc[df["order"] == "Gadiformes", "class"] = "Actinopterygii"
df.loc[df["order"] == "Mugiliformes", "class"] = "Actinopterygii"
df.loc[df["order"] == "Gobiesociformes", "class"] = "Actinopterygii"
df.loc[df["order"] == "Acipenseriformes", "class"] = "Actinopterygii"
df.loc[df["order"] == "Myctophiformes", "class"] = "Actinopterygii"
df.loc[df["order"] == "Beryciformes", "class"] = "Actinopterygii"
df.loc[df["order"] == "Gymnotiformes", "class"] = "Actinopterygii"
df.loc[df["order"] == "Lampriformes", "class"] = "Actinopterygii"
df.loc[df["order"] == "Polypteriformes", "class"] = "Actinopterygii"
df.loc[df["order"] == "Esociformes", "class"] = "Actinopterygii"
df.loc[df["order"] == "Stomiiformes", "class"] = "Actinopterygii"
df.loc[df["order"] == "Albuliformes", "class"] = "Actinopterygii"
df.loc[df["order"] == "Elopiformes", "class"] = "Actinopterygii"
df.loc[df["order"] == "Gasterosteiformes", "class"] = "Actinopterygii"
df.loc[df["order"] == "Percopsiformes", "class"] = "Actinopterygii"
df.loc[df["order"] == "Zeiformes", "class"] = "Actinopterygii"
df.loc[df["order"] == "Notacanthiformes", "class"] = "Actinopterygii"

# %%
df.loc[df["order"] == "Asterales", "class"] = "Magnoliopsida"
df.loc[df["order"] == "Fabales", "class"] = "Magnoliopsida"
df.loc[df["order"] == "Caryophyllales", "class"] = "Magnoliopsida"
df.loc[df["order"] == "Lamiales", "class"] = "Magnoliopsida"
df.loc[df["order"] == "Rosales", "class"] = "Magnoliopsida"
df.loc[df["order"] == "Ericales", "class"] = "Magnoliopsida"
df.loc[df["order"] == "Myrtales", "class"] = "Magnoliopsida"
df.loc[df["order"] == "Brassicales", "class"] = "Magnoliopsida"
df.loc[df["order"] == "Boraginales", "class"] = "Magnoliopsida"
df.loc[df["order"] == "Apiales", "class"] = "Magnoliopsida"
df.loc[df["order"] == "Ranunculales", "class"] = "Magnoliopsida"
df.loc[df["order"] == "Saxifragales", "class"] = "Magnoliopsida"
df.loc[df["order"] == "Malpighiales", "class"] = "Magnoliopsida"

# %%
df.loc[df["order"] == "Poales", "class"] = "Liliopsida"
df.loc[df["order"] == "Asparagales", "class"] = "Liliopsida"

# %%
df.loc[df["order"] == "Lepidoptera", "class"] = "Insecta"
df.loc[df["order"] == "Hemiptera", "class"] = "Insecta"
df.loc[df["order"] == "Diptera", "class"] = "Insecta"
df.loc[df["order"] == "Coleoptera", "class"] = "Insecta"

# %%
df.loc[df["order"] == "Ceratodontiformes", "class"] = "Sarcopterygii"

# %%
df.loc[df["order"] == "Copelata", "class"] = "Appendicularia"

# %%
df.loc[df["order"] == "Anura", "class"] = "Amphibia"

# %%
df.loc[df["order"] == "Armophorida", "class"] = "Armophorea"

# %%
# find the class value counts in na_phylum

na_phylum["class"].value_counts()

# %%
# del Liliopsida
# Liliopsida = df[(df["class"] == "Liliopsida")]

# %%
# Liliopsida["phylum"].value_counts()

# %%
# if class is Aves, Reptilia, Aves, or Mammalia set phylum to Chordata

df.loc[df["class"] == "Aves", "phylum"] = "Chordata"
df.loc[df["class"] == "Mammalia", "phylum"] = "Chordata"
df.loc[df["class"] == "Reptilia", "phylum"] = "Chordata"
df.loc[df["class"] == "Amphibia", "phylum"] = "Chordata"
df.loc[df["class"] == "Actinopterygii", "phylum"] = "Chordata"

# %%
df.loc[df["class"] == "Insecta", "phylum"] = "Arthropoda"

# %%
df.loc[df["class"] == "Florideophyceae", "phylum"] = "Rhodophyta"

# %%
df.loc[df["class"] == "Ulvophyceae", "phylum"] = "Chlorophyta"
df.loc[df["class"] == "Pyramimonadophyceae", "phylum"] = "Chlorophyta"

# %%
df.loc[df["class"] == "Filosia", "phylum"] = "Cercozoa"

# %%
df.loc[df["class"] == "Magnoliopsida", "phylum"] = "Tracheophyta"
df.loc[df["class"] == "Liliopsida", "phylum"] = "Tracheophyta"

# %%
df.loc[df["class"] == "Crocodylia", "order"] = "Crocodylia"
df.loc[df["order"] == "Crocodylia", "class"] = "Reptilia"

# %%
df.loc[df["class"] == "Armophorea", "phylum"] = "Ciliophora"

# %%
df.loc[df["phylum"] == "Ciliophora", "kingdom"] = "Chromista"

# %%
del (
    class_unique,
    na_class,
    na_phylum,
    na_kingdom,
    na_order,
    na_family,
    na_genus,
    family_unique,
    genus_unique,
    order_unique,
    phylum_unique,
)

# %%
# find values in genus values that contain special characters and remove them

df = df[~df.genus.str.contains("[^a-zA-Z-\s]")]

# %%
# does not work if na values present
df = df[
    ~df.kingdom.str.contains(
        "[^a-zA-Z-\s]",
    )
]
df = df[
    ~df.phylum.str.contains(
        "[^a-zA-Z-\s]",
    )
]
df = df[
    ~df["class"].str.contains(
        "[^a-zA-Z-\s]",
    )
]
df = df[
    ~df.order.str.contains(
        "[^a-zA-Z-\s]",
    )
]

df = df[
    ~df.family.str.contains(
        "[^a-zA-Z-\s]",
    )
]

# %%
# if class is Amphibia, Reptilia, Aves, or Mammalia set kingdom to Animalia

# df.loc[df["class"] == "Amphibia", "kingdom"] = "Animalia"

# df.loc[df["class"] == "Reptilia", "kingdom"] = "Animalia"

# df.loc[df["class"] == "Aves", "kingdom"] = "Animalia"

# df.loc[df["class"] == "Mammalia", "kingdom"] = "Animalia"

# %%
# if species_type is tree_shrub, wildflower, graminoid, other_plants, vine, water_master, or uncategorized_plants, set kingdom to Plantae

df.loc[df["species_type"] == "tree_shrub", "kingdom"] = "Plantae"

df.loc[df["species_type"] == "wildflower", "kingdom"] = "Plantae"

df.loc[df["species_type"] == "graminoid", "kingdom"] = "Plantae"

df.loc[df["species_type"] == "other_plants", "kingdom"] = "Plantae"

df.loc[df["species_type"] == "vine", "kingdom"] = "Plantae"

df.loc[df["species_type"] == "water_master", "kingdom"] = "Plantae"

df.loc[df["species_type"] == "uncategorized_plants", "kingdom"] = "Plantae"

# %%
# if species_type is fish, worm, bird, reptile, amphibian, or other_animals, set kingdom to Animalia

# %%
df.loc[df["kingdom"] == "Bacteria", "species_type"] = "bacteria"
df.loc[df["kingdom"] == "Protozoa", "species_type"] = "protozoa"
df.loc[df["kingdom"] == "Viruses", "species_type"] = "virus"
df.loc[df["kingdom"] == "Chromista", "species_type"] = "chromista"
df.loc[df["kingdom"] == "Archaea", "species_type"] = "archaea"

# %%
del (
    archaea,
    bacteria,
    chromista,
    protozoa,
    virus,
    na_archaea,
    na_bacteria,
    na_chromista,
    na_protozoa,
    na_virus,
)

# %%
df.loc[df["phylum"] == "Arthropoda", "species_type"] = "arthropod"

df.loc[df["phylum"] == "Entoprocta", "species_type"] = "worm"

df.loc[df["phylum"] == "Priapulida", "species_type"] = "worm"

df.loc[df["phylum"] == "Kinorhyncha", "species_type"] = "worm"

df.loc[df["phylum"] == "Acanthocephala", "species_type"] = "worm"

df.loc[df["phylum"] == "Mollusca", "species_type"] = "mollusk"

df.loc[df["phylum"] == "Cnidaria", "species_type"] = "cnidaria"

df.loc[df["phylum"] == "Kamptozoa", "species_type"] = "other_animals"

df.loc[df["phylum"] == "Placozoa", "species_type"] = "other_animals"

df.loc[df["phylum"] == "Chlorophyta", "species_type"] = "green algae"

df.loc[df["phylum"] == "Charophyta", "species_type"] = "green algae"

df.loc[df["phylum"] == "Bryophyta", "species_type"] = "moss"

df.loc[df["phylum"] == "Rhodophyta", "species_type"] = "red algae"

df.loc[df["phylum"] == "Glaucophyta", "species_type"] = "algae"

# %%
df.loc[df["phylum"] == "Porifera", "species_type"] = "sponge"

df.loc[df["phylum"] == "Annelida", "species_type"] = "round worm"

df.loc[df["phylum"] == "Echinodermata", "species_type"] = "echinoderm"

df.loc[df["phylum"] == "Bryozoa", "species_type"] = "bryozoa"

df.loc[df["phylum"] == "Rotifera", "species_type"] = "rotifer"

df.loc[df["phylum"] == "Platyhelminthes", "species_type"] = "flat worm"

df.loc[df["phylum"] == "Nemertea", "species_type"] = "ribbon worm"

df.loc[df["phylum"] == "Onychophora", "species_type"] = "velvet worm"

df.loc[df["phylum"] == "Nematoda", "species_type"] = "nematode"

df.loc[df["phylum"] == "Ctenophora", "species_type"] = "comb jelly"

df.loc[df["phylum"] == "Brachiopoda", "species_type"] = "brachiopod"

df.loc[df["phylum"] == "Gastrotricha", "species_type"] = "hairy belly"

df.loc[df["phylum"] == "Tardigrada", "species_type"] = "tardigrade"

df.loc[df["phylum"] == "Sipuncula", "species_type"] = "peanut worm"

df.loc[df["phylum"] == "Nematomorpha", "species_type"] = "horsehair worm"

df.loc[df["phylum"] == "Chaetognatha", "species_type"] = "arrow worm"

df.loc[df["phylum"] == "Phoronida", "species_type"] = "horseshoe worm"

df.loc[df["phylum"] == "Hemichordata", "species_type"] = "acorn worm"

df.loc[df["phylum"] == "Xenacoelomorpha", "species_type"] = "xenacoelomorph"

df.loc[df["phylum"] == "Ciliophora", "species_type"] = "ciliate"

# %%
df.loc[df["class"] == "Leptocardii", "species_type"] = "fish"

df.loc[df["class"] == "Lecanoromycetes", "species_type"] = "lichenized fungi"

df.loc[df["class"] == "Ustilaginomycetes", "species_type"] = "smut fungi"

df.loc[df["class"] == "Dacrymycetes", "species_type"] = "jelly fungi"

df.loc[df["class"] == "Geoglossomycetes", "species_type"] = "earth tongue"

df.loc[df["class"] == "Saccharomycetes", "species_type"] = "budding yeast"

df.loc[df["class"] == "Neolectomycetes", "species_type"] = "earth tongue like"

# %%
df.loc[df["class"] == "Mammalia", "species_type"] = "mammal"

df.loc[df["class"] == "Amphibia", "species_type"] = "amphibian"

df.loc[df["class"] == "Reptilia", "species_type"] = "reptile"

df.loc[df["class"] == "Aves", "species_type"] = "bird"

df.loc[df["class"] == "Insecta", "species_type"] = "insect"

df.loc[df["class"] == "Arachnida", "species_type"] = "arachnid"

df.loc[df["class"] == "Diplopoda", "species_type"] = "millipede"

df.loc[df["class"] == "Actinopterygii", "species_type"] = "ray fin fish"

df.loc[df["class"] == "Actinopteri", "species_type"] = "ray fin fish"

df.loc[df["class"] == "Bacillariophyceae", "species_type"] = "diatom"

df.loc[df["class"] == "Phaeophyceae", "species_type"] = "brown algae"

df.loc[df["class"] == "Dinophyceae", "species_type"] = "dinoflagellate"

df.loc[df["class"] == "Prymnesiophyceae", "species_type"] = "algae"

df.loc[df["class"] == "Dictyochophyceae", "species_type"] = "heterokont algae"

df.loc[df["class"] == "Chrysophyceae", "species_type"] = "golden brown algae"

df.loc[df["class"] == "Oligohymenophorea", "species_type"] = "ciliate"

df.loc[df["class"] == "Heterotrichea", "species_type"] = "ciliate"

# %%
df.loc[df["class"] == "Hypotrichea", "species_type"] = "ciliate"

df.loc[df["class"] == "Solenogastres", "species_type"] = "solenogaster"

df.loc[df["class"] == "Gastropoda", "species_type"] = "slug/snail"

df.loc[df["class"] == "Bivalvia", "species_type"] = "bivalve"

df.loc[df["class"] == "Malacostraca", "species_type"] = "malacostracan"

df.loc[df["class"] == "Polyplacophora", "species_type"] = "chiton"

df.loc[df["class"] == "Pycnogonida", "species_type"] = "sea spider"

df.loc[df["class"] == "Scyphozoa", "species_type"] = "jellyfish"

df.loc[df["class"] == "Elasmobranchii", "species_type"] = "cartilaginous fish"

df.loc[df["class"] == "Hydrozoa", "species_type"] = "hydrozoan"

df.loc[df["class"] == "Ascidiacea", "species_type"] = "ascidian"

df.loc[df["class"] == "Chilopoda", "species_type"] = "centipede"

df.loc[df["class"] == "Cubozoa", "species_type"] = "jellyfish"

df.loc[df["class"] == "Collembola", "species_type"] = "springtail"

df.loc[df["class"] == "Cephalopoda", "species_type"] = "cephalopod"

df.loc[df["class"] == "Scaphopoda", "species_type"] = "tusk shell"

df.loc[df["class"] == "Ostracoda", "species_type"] = "ostracod"

df.loc[df["class"] == "Holocephali", "species_type"] = "cartilaginous fish"

df.loc[df["class"] == "Staurozoa", "species_type"] = "jellyfish"

df.loc[df["class"] == "Merostomata", "species_type"] = "horseshoe crab"

df.loc[df["class"] == "Prasinophyceae", "species_type"] = "green algae"

df.loc[df["class"] == "Rhodellophyceae", "species_type"] = "red algae"

# %%
df.loc[df["class"] == "Myxini", "species_type"] = "hagfish"

df.loc[df["class"] == "Sarcopterygii", "species_type"] = "lobe fin fish"

df.loc[df["class"] == "Appendicularia", "species_type"] = "larvacean"

df.loc[df["class"] == "Anthozoa", "species_type"] = "coral/anemone"

df.loc[df["class"] == "Cephalaspidomorphi", "species_type"] = "lamprey"

df.loc[df["class"] == "Petromyzonti", "species_type"] = "lamprey"

df.loc[df["class"] == "Pinopsida", "species_type"] = "tree/shrub"

df.loc[df["class"] == "Bryopsida", "species_type"] = "moss"

df.loc[df["class"] == "Polypodiopsida", "species_type"] = "fern"

df.loc[df["class"] == "Florideophyceae", "species_type"] = "red algae"

df.loc[df["class"] == "Ulvophyceae", "species_type"] = "green algae"

df.loc[df["class"] == "Trebouxiophyceae", "species_type"] = "green algae"

df.loc[df["class"] == "Zygnematophyceae", "species_type"] = "green algae"

df.loc[df["class"] == "Andreaeopsida", "species_type"] = "moss"

df.loc[df["class"] == "Chlorophyceae", "species_type"] = "green algae"

df.loc[df["class"] == "Bangiophyceae", "species_type"] = "red algae"

df.loc[df["class"] == "Cycadopsida", "species_type"] = "cycad"

df.loc[df["class"] == "Charophyceae", "species_type"] = "green algae"

df.loc[df["class"] == "Compsopogonophyceae", "species_type"] = "red algae"

df.loc[df["class"] == "Lycopodiopsida", "species_type"] = "lycopod"

df.loc[df["class"] == "Ginkgoopsida", "species_type"] = "tree/shrub"

df.loc[df["class"] == "Klebsormidiophyceae", "species_type"] = "green algae"

df.loc[df["class"] == "Pyramimonadophyceae", "species_type"] = "green algae"

df.loc[df["class"] == "Sphagnopsida", "species_type"] = "moss"

df.loc[df["class"] == "Haplomitriopsida", "species_type"] = "liverwort"

df.loc[df["class"] == "Jungermanniopsida", "species_type"] = "liverwort"

df.loc[df["class"] == "Anthocerotopsida", "species_type"] = "hornwort"

df.loc[df["class"] == "Marchantiopsida", "species_type"] = "liverwort"

df.loc[df["class"] == "Gnetopsida", "species_type"] = "gnetophyte"

df.loc[df["class"] == "Thaliacea", "species_type"] = "other_animals"

# %%
df.loc[df["order"] == "Scorpaeniformes", "species_type"] = "fish"

df.loc[df["order"] == "Verrucariales", "species_type"] = "lichenized fungi"

df.loc[df["order"] == "Arthoniales", "species_type"] = "lichenized fungi"

df.loc[df["order"] == "Eurotiales", "species_type"] = "green and blue mold"

df.loc[df["order"] == "Lichinales", "species_type"] = "lichenized fungi"

df.loc[df["order"] == "Trypetheliales", "species_type"] = "lichenized fungi"

df.loc[df["order"] == "Mucorales", "species_type"] = "pin mold"

df.loc[df["order"] == "Entylomatales", "species_type"] = "smut fungi"

df.loc[df["order"] == "Lepidostromatales", "species_type"] = "lichenized club fungi"

df.loc[df["order"] == "Poales", "species_type"] = "graminoid"

df.loc[df["order"] == "Pucciniales", "species_type"] = "rust fungi"

df.loc[df["order"] == "Agaricales", "species_type"] = "agaric"

df.loc[df["order"] == "Peltigerales", "species_type"] = "lichenized fungi"

# %%
df.loc[df["order"] == "Diplostraca", "species_type"] = "water flea"

df.loc[df["order"] == "Anostraca", "species_type"] = "fairy shrimp"

df.loc[df["order"] == "Cyclopoida", "species_type"] = "plankton"

df.loc[df["order"] == "Cyclopoida", "species_type"] = "barnacle"

df.loc[df["order"] == "Salpida", "species_type"] = "salp"

df.loc[df["order"] == "Pedunculata", "species_type"] = "barnacle"

df.loc[df["order"] == "Notostraca", "species_type"] = "tadpole shrimp"

df.loc[df["order"] == "Diplura", "species_type"] = "dipluran"

df.loc[df["order"] == "Calanoida", "species_type"] = "plankton"

df.loc[df["order"] == "Kentrogonida", "species_type"] = "barnacle"

df.loc[df["order"] == "Arguloida", "species_type"] = "fish lice"

# %%
df.loc[df["family"] == "Nymphaeaceae", "species_type"] = "aquatic"

df.loc[df["family"] == "Potamogetonaceae", "species_type"] = "aquatic"

df.loc[df["family"] == "Cantharellaceae", "species_type"] = "gill like"

df.loc[df["family"] == "Phanerochaetaceae", "species_type"] = "crust fungi"

df.loc[df["family"] == "Stereaceae", "species_type"] = "crust fungi"

df.loc[df["family"] == "Sarcoscyphaceae", "species_type"] = "cup fungi"

df.loc[df["family"] == "Thelephoraceae", "species_type"] = "leathery earthfan"

df.loc[df["family"] == "Coniocybaceae", "species_type"] = "lichenized fungi"

df.loc[df["family"] == "Dermateaceae", "species_type"] = "cup fungi"

df.loc[df["family"] == "Atheliaceae", "species_type"] = "crust fungi"

df.loc[df["family"] == "Pyrenulaceae", "species_type"] = "lichenized fungi"


df.loc[df["family"] == "Balanidae", "species_type"] = "barnacle"

df.loc[df["family"] == "Daphniidae", "species_type"] = "water flea"

df.loc[df["family"] == "Chthamalidae", "species_type"] = "barnacle"

df.loc[df["family"] == "Chydoridae", "species_type"] = "water flea"

df.loc[df["family"] == "Lepadidae", "species_type"] = "barnacle"

df.loc[df["family"] == "Tetraclitidae", "species_type"] = "barnacle"

# %%
df.loc[df["family"] == "Phallaceae", "species_type"] = "stinkhorn"

df.loc[df["family"] == "Acarosporaceae", "species_type"] = "lichenized fungi"

df.loc[df["family"] == "Arthoniaceae", "species_type"] = "lichenized fungi"

df.loc[df["family"] == "Cladoniaceae", "species_type"] = "lichenized fungi"

df.loc[df["family"] == "Candelariaceae", "species_type"] = "lichenized fungi"

df.loc[df["family"] == "Boletaceae", "species_type"] = "bolete"

df.loc[df["family"] == "Auriculariaceae", "species_type"] = "jelly fungi"

# %%
df.loc[df["family"] == "Ganodermataceae", "species_type"] = "polypore"

df.loc[df["family"] == "Geastraceae", "species_type"] = "earthstar"

df.loc[df["family"] == "Physciaceae", "species_type"] = "lichenized fungi"

df.loc[df["family"] == "Parmeliaceae", "species_type"] = "lichenized fungi"

df.loc[df["family"] == "Lecanoraceae", "species_type"] = "lichenized fungi"

df.loc[df["family"] == "Polyporaceae", "species_type"] = "polypore"

df.loc[df["family"] == "Collemataceae", "species_type"] = "lichenized fungi"

df.loc[df["family"] == "Ochrolechiaceae", "species_type"] = "lichenized fungi"

df.loc[df["family"] == "Pannariaceae", "species_type"] = "lichenized fungi"

df.loc[df["family"] == "Peltigeraceae", "species_type"] = "lichenized fungi"

df.loc[df["family"] == "Pertusariaceae", "species_type"] = "lichenized fungi"

df.loc[df["family"] == "Pezizaceae", "species_type"] = "cup fungi"

df.loc[df["family"] == "Lobariaceae", "species_type"] = "lichenized fungi"

df.loc[df["family"] == "Ramalinaceae", "species_type"] = "lichenized fungi"


df.loc[df["family"] == "Orchidaceae", "species_type"] = "orchid"

df.loc[df["family"] == "Salicaceae", "species_type"] = "tree/shrub"

df.loc[df["family"] == "Rousseaceae", "species_type"] = "tree/shrub"

df.loc[df["family"] == "Cactaceae", "species_type"] = "cactus"

df.loc[df["family"] == "Aizoaceae", "species_type"] = "succulent"

df.loc[df["family"] == "Crassulaceae", "species_type"] = "succulent"

# %%
df.loc[df["genus"] == "Palaeomystella", "species_type"] = "arthropod"

df.loc[df["genus"] == "Phyllodonta", "species_type"] = "arthropod"

df.loc[df["genus"] == "Archaeoaenetus", "species_type"] = "arthropod"

df.loc[df["genus"] == "Hammatoderus", "species_type"] = "arthropod"

df.loc[df["genus"] == "Mnesarchella", "species_type"] = "arthropod"

df.loc[df["genus"] == "Vaejovis", "species_type"] = "arthropod"

df.loc[df["genus"] == "Chlorocalis", "species_type"] = "arthropod"

# %%
df.loc[df["genus"] == "Macaranga", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Hirschfeldia", "species_type"] = "wildflower"

df.loc[df["genus"] == "Crithmum", "species_type"] = "wildflower"

df.loc[df["genus"] == "Antigonon", "species_type"] = "vine"

df.loc[df["genus"] == "Juglans", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Stylophorum", "species_type"] = "wildflower"

df.loc[df["genus"] == "Onopordum", "species_type"] = "wildflower"

df.loc[df["genus"] == "Rhodotypos", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Olea", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Muscari", "species_type"] = "wildflower"

df.loc[df["genus"] == "Cercocarpus", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Mentha", "species_type"] = "wildflower"

df.loc[df["genus"] == "Psidium", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Caulophyllum", "species_type"] = "wildflower"

df.loc[df["genus"] == "Calendula", "species_type"] = "wildflower"

# %%
df.loc[df["genus"] == "Melissa", "species_type"] = "wildflower"

df.loc[df["genus"] == "Burchardia", "species_type"] = "wildflower"

df.loc[df["genus"] == "Arbutus", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Hyacinthoides", "species_type"] = "wildflower"

df.loc[df["genus"] == "Colocasia", "species_type"] = "wildflower"

df.loc[df["genus"] == "Pyrola", "species_type"] = "wildflower"

df.loc[df["genus"] == "Delairea", "species_type"] = "vine"

df.loc[df["genus"] == "Richardia", "species_type"] = "wildflower"

df.loc[df["genus"] == "Cistus", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Cyclamen", "species_type"] = "wildflower"

df.loc[df["genus"] == "Leopoldia", "species_type"] = "wildflower"

df.loc[df["genus"] == "Arabidopsis", "species_type"] = "wildflower"

df.loc[df["genus"] == "Punica", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Bellardia", "species_type"] = "wildflower"

df.loc[df["genus"] == "Myriophyllum", "species_type"] = "aquatic"

df.loc[df["genus"] == "Cynara", "species_type"] = "wildflower"

df.loc[df["genus"] == "Parietaria", "species_type"] = "wildflower"

df.loc[df["genus"] == "Descurainia", "species_type"] = "wildflower"

df.loc[df["genus"] == "Galeopsis", "species_type"] = "wildflower"

df.loc[df["genus"] == "Buglossoides", "species_type"] = "wildflower"

df.loc[df["genus"] == "Cannabis", "species_type"] = "wildflower"

df.loc[df["genus"] == "Cotinus", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Lathraea", "species_type"] = "wildflower"

df.loc[df["genus"] == "Mangifera", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Casuarina", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Amaryllis", "species_type"] = "wildflower"

# %%
df.loc[df["genus"] == "Fraxinus", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Maianthemum", "species_type"] = "wildflower"

df.loc[df["genus"] == "Schinus", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Lycopus", "species_type"] = "wildflower"

df.loc[df["genus"] == "Torilis", "species_type"] = "wildflower"

df.loc[df["genus"] == "Adelinia", "species_type"] = "wildflower"

df.loc[df["genus"] == "Arum", "species_type"] = "wildflower"

df.loc[df["genus"] == "Borago", "species_type"] = "wildflower"

df.loc[df["genus"] == "Viscum", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Asarum", "species_type"] = "wildflower"

df.loc[df["genus"] == "Pentaglottis", "species_type"] = "wildflower"

df.loc[df["genus"] == "Zantedeschia", "species_type"] = "wildflower"

df.loc[df["genus"] == "Tilia", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Paris", "species_type"] = "wildflower"

df.loc[df["genus"] == "Catharanthus", "species_type"] = "wildflower"

df.loc[df["genus"] == "Pyrus", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Symphytum", "species_type"] = "wildflower"

df.loc[df["genus"] == "Agrimonia", "species_type"] = "wildflower"

df.loc[df["genus"] == "Cornus", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Syringa", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Cocos", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Pontederia", "species_type"] = "aquatic"

df.loc[df["genus"] == "Melampyrum", "species_type"] = "wildflower"

df.loc[df["genus"] == "Pulmonaria", "species_type"] = "wildflower"

df.loc[df["genus"] == "Lobularia", "species_type"] = "wildflower"

df.loc[df["genus"] == "Carpinus", "species_type"] = "tree/shrub"

# %%
df.loc[df["genus"] == "Hippophae", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Carpobrotus", "species_type"] = "succulent"

df.loc[df["genus"] == "Nerium", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Anemone", "species_type"] = "wildflower"

df.loc[df["genus"] == "Alisma", "species_type"] = "aquatic"

df.loc[df["genus"] == "Hemerocallis", "species_type"] = "wildflower"

df.loc[df["genus"] == "Malus", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Bunias", "species_type"] = "wildflower"

df.loc[df["genus"] == "Spartium", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Cosmos", "species_type"] = "wildflower"

df.loc[df["genus"] == "Castanea", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Pterospora", "species_type"] = "wildflower"

df.loc[df["genus"] == "Leucaena", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Carica", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Picris", "species_type"] = "wildflower"

df.loc[df["genus"] == "Chrysosplenium", "species_type"] = "wildflower"

df.loc[df["genus"] == "Rhinanthus", "species_type"] = "wildflower"

df.loc[df["genus"] == "Sapindus", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Fragaria", "species_type"] = "wildflower"

df.loc[df["genus"] == "Bistorta", "species_type"] = "wildflower"

df.loc[df["genus"] == "Modiola", "species_type"] = "wildflower"

df.loc[df["genus"] == "Dermatophyllum", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Ruscus", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Plectocephalus", "species_type"] = "wildflower"

df.loc[df["genus"] == "Caragana", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Ulmus", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Houstonia", "species_type"] = "wildflower"

df.loc[df["genus"] == "Eranthis", "species_type"] = "wildflower"

df.loc[df["genus"] == "Cota", "species_type"] = "wildflower"

df.loc[df["genus"] == "Pistacia", "species_type"] = "tree/shrub"

# %%
df.loc[df["genus"] == "Glechoma", "species_type"] = "wildflower"

df.loc[df["genus"] == "Cichorium", "species_type"] = "wildflower"

df.loc[df["genus"] == "Ficaria", "species_type"] = "wildflower"

df.loc[df["genus"] == "Lamium", "species_type"] = "wildflower"

df.loc[df["genus"] == "Daucus", "species_type"] = "wildflower"

df.loc[df["genus"] == "Hedera", "species_type"] = "vine"

df.loc[df["genus"] == "Tussilago", "species_type"] = "wildflower"

df.loc[df["genus"] == "Chelidonium", "species_type"] = "wildflower"

df.loc[df["genus"] == "Ailanthus", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Lythrum", "species_type"] = "wildflower"

df.loc[df["genus"] == "Bellis", "species_type"] = "wildflower"

df.loc[df["genus"] == "Capsella", "species_type"] = "wildflower"

df.loc[df["genus"] == "Leucanthemum", "species_type"] = "wildflower"

df.loc[df["genus"] == "Lamium", "species_type"] = "wildflower"

df.loc[df["genus"] == "Reynoutria", "species_type"] = "wildflower"

df.loc[df["genus"] == "Dipsacus", "species_type"] = "wildflower"

df.loc[df["genus"] == "Sorbus", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Aegopodium", "species_type"] = "wildflower"

df.loc[df["genus"] == "Ricinus", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Saponaria", "species_type"] = "wildflower"

df.loc[df["genus"] == "Filipendula", "species_type"] = "wildflower"

df.loc[df["genus"] == "Anthriscus", "species_type"] = "wildflower"

df.loc[df["genus"] == "Frangula", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Cytisus", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Corylus", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Betula", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Calyptocarpus", "species_type"] = "wildflower"

df.loc[df["genus"] == "Barbarea", "species_type"] = "wildflower"

df.loc[df["genus"] == "Elaeagnus", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Rabelera", "species_type"] = "wildflower"

df.loc[df["genus"] == "Ligustrum", "species_type"] = "tree/shrub"

# %%
df.loc[df["genus"] == "Humulus", "species_type"] = "vine"

df.loc[df["genus"] == "Thlaspi", "species_type"] = "wildflower"

df.loc[df["genus"] == "Fagus", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Nandina", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Sherardia", "species_type"] = "wildflower"

df.loc[df["genus"] == "Calluna", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Melia", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Centranthus", "species_type"] = "wildflower"

df.loc[df["genus"] == "Calystegia", "species_type"] = "vine"

df.loc[df["genus"] == "Conium", "species_type"] = "wildflower"

df.loc[df["genus"] == "Alnus", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Raphanus", "species_type"] = "wildflower"

df.loc[df["genus"] == "Aesculus", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Galanthus", "species_type"] = "wildflower"

df.loc[df["genus"] == "Morus", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Paulownia", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Hepatica", "species_type"] = "wildflower"

df.loc[df["genus"] == "Origanum", "species_type"] = "wildflower"

df.loc[df["genus"] == "Silybum", "species_type"] = "wildflower"

df.loc[df["genus"] == "Arctium", "species_type"] = "wildflower"

df.loc[df["genus"] == "Ulex", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Arctium", "species_type"] = "wildflower"

df.loc[df["genus"] == "Anemonastrum", "species_type"] = "wildflower"

df.loc[df["genus"] == "Dipterostemon", "species_type"] = "wildflower"

df.loc[df["genus"] == "Heracleum", "species_type"] = "wildflower"

df.loc[df["genus"] == "Monotropa", "species_type"] = "wildflower"

df.loc[df["genus"] == "Datura", "species_type"] = "wildflower"

df.loc[df["genus"] == "Youngia", "species_type"] = "wildflower"

df.loc[df["genus"] == "Broussonetia", "species_type"] = "tree/shrub"

# %%
df.loc[df["genus"] == "Posidonia", "species_type"] = "aquatic"

df.loc[df["genus"] == "Acorus", "species_type"] = "graminoid"

df.loc[df["genus"] == "Zizania", "species_type"] = "aquatic"

df.loc[df["genus"] == "Sagittaria", "species_type"] = "aquatic"

df.loc[df["genus"] == "Pistia", "species_type"] = "aquatic"

df.loc[df["genus"] == "Lemna", "species_type"] = "aquatic"

df.loc[df["genus"] == "Wolffia", "species_type"] = "aquatic"

df.loc[df["genus"] == "Hydrocharis", "species_type"] = "aquatic"

df.loc[df["genus"] == "Calochortus", "species_type"] = "wildflower"

df.loc[df["genus"] == "Cotula", "species_type"] = "wildflower"

df.loc[df["genus"] == "Scilla", "species_type"] = "wildflower"

df.loc[df["genus"] == "Sterculia", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Pseudognaphalium", "species_type"] = "wildflower"

df.loc[df["genus"] == "Cymopterus", "species_type"] = "wildflower"

df.loc[df["genus"] == "Anthemis", "species_type"] = "wildflower"

df.loc[df["genus"] == "Pomaderris", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Hypochaeris", "species_type"] = "wildflower"

df.loc[df["genus"] == "Elaeocarpus", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Lachnaea", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Ixora", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Cestrum", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Cyrtanthus", "species_type"] = "wildflower"

# %%
df.loc[df["genus"] == "Epacris", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Ligularia", "species_type"] = "wildflower"

df.loc[df["genus"] == "Nepenthes", "species_type"] = "vine"

df.loc[df["genus"] == "Daphne", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Navarretia", "species_type"] = "wildflower"

df.loc[df["genus"] == "Tanacetum", "species_type"] = "wildflower"

df.loc[df["genus"] == "Dracocephalum", "species_type"] = "wildflower"

df.loc[df["genus"] == "Erepsia", "species_type"] = "succulent"

df.loc[df["genus"] == "Anchusa", "species_type"] = "wildflower"

df.loc[df["genus"] == "Garcinia", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Ajuga", "species_type"] = "wildflower"

df.loc[df["genus"] == "Spiraea", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Rhamnus", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Ocotea", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Phoradendron", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Narcissus", "species_type"] = "wildflower"

df.loc[df["genus"] == "Phlox", "species_type"] = "wildflower"

df.loc[df["genus"] == "Haworthia", "species_type"] = "succulent"

df.loc[df["genus"] == "Annona", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Diascia", "species_type"] = "wildflower"

df.loc[df["genus"] == "Fumaria", "species_type"] = "wildflower"

df.loc[df["genus"] == "Ayenia", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Geum", "species_type"] = "wildflower"

df.loc[df["genus"] == "Roldana", "species_type"] = "wildflower"

df.loc[df["genus"] == "Trillium", "species_type"] = "wildflower"

df.loc[df["genus"] == "Vitis", "species_type"] = "vine"

df.loc[df["genus"] == "Litsea", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Salicornia", "species_type"] = "succulent"

df.loc[df["genus"] == "Amyema", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Chorizanthe", "species_type"] = "wildflower"

df.loc[df["genus"] == "Xanthorrhoea", "species_type"] = "grasstree"

df.loc[df["genus"] == "Nymphaea", "species_type"] = "aquatic"

df.loc[df["genus"] == "Petrophile", "species_type"] = "tree/shrub"

# %%
df.loc[df["genus"] == "Alpinia", "species_type"] = "wildflower"

df.loc[df["genus"] == "Ludwigia", "species_type"] = "aquatic"

df.loc[df["genus"] == "Banksia", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Pittosporum", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Paronychia", "species_type"] = "wildflower"

df.loc[df["genus"] == "Androsace", "species_type"] = "wildflower"

df.loc[df["genus"] == "Hypoxis", "species_type"] = "wildflower"

df.loc[df["genus"] == "Vincetoxicum", "species_type"] = "vine"

df.loc[df["genus"] == "Lomatium", "species_type"] = "wildflower"

df.loc[df["genus"] == "Boechera", "species_type"] = "wildflower"

df.loc[df["genus"] == "Vaccinium", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Tabernaemontana", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Hesperantha", "species_type"] = "wildflower"

df.loc[df["genus"] == "Lippia", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Echinops", "species_type"] = "wildflower"

df.loc[df["genus"] == "Commelina", "species_type"] = "wildflower"

df.loc[df["genus"] == "Mandevilla", "species_type"] = "vine"

df.loc[df["genus"] == "Bursera", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Angelica", "species_type"] = "wildflower"

df.loc[df["genus"] == "Diplacus", "species_type"] = "wildflower"

df.loc[df["genus"] == "Carduus", "species_type"] = "wildflower"

df.loc[df["genus"] == "Albizia", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Bossiaea", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Aristea", "species_type"] = "wildflower"

df.loc[df["genus"] == "Fuchsia", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Glandularia", "species_type"] = "wildflower"

df.loc[df["genus"] == "Sonchus", "species_type"] = "wildflower"

df.loc[df["genus"] == "Arctotis", "species_type"] = "wildflower"

df.loc[df["genus"] == "Seseli", "species_type"] = "wildflower"

df.loc[df["genus"] == "Streptocarpus", "species_type"] = "wildflower"

df.loc[df["genus"] == "Arisaema", "species_type"] = "wildflower"

df.loc[df["genus"] == "Alstroemeria", "species_type"] = "wildflower"

df.loc[df["genus"] == "Dracaena", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Nepeta", "species_type"] = "wildflower"

df.loc[df["genus"] == "Commiphora", "species_type"] = "tree/shrub"

# %%
df.loc[df["genus"] == "Aciphylla", "species_type"] = "wildflower"

df.loc[df["genus"] == "Cryptocarya", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Pauridia", "species_type"] = "wildflower"

df.loc[df["genus"] == "Reseda", "species_type"] = "wildflower"

df.loc[df["genus"] == "Erythroxylum", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Allocasuarina", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Crinum", "species_type"] = "wildflower"

df.loc[df["genus"] == "Vitex", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Lomandra", "species_type"] = "graminoid"

df.loc[df["genus"] == "Gymnosporia", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Portulaca", "species_type"] = "wildflower"

df.loc[df["genus"] == "Dodonaea", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Zaluzianskya", "species_type"] = "wildflower"

df.loc[df["genus"] == "Espeletia", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Physaria", "species_type"] = "wildflower"

df.loc[df["genus"] == "Arabis", "species_type"] = "wildflower"

df.loc[df["genus"] == "Bulbine", "species_type"] = "succulent"

df.loc[df["genus"] == "Centella", "species_type"] = "wildflower"

df.loc[df["genus"] == "Corymbia", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Goeppertia", "species_type"] = "wildflower"

df.loc[df["genus"] == "Gypsophila", "species_type"] = "wildflower"

df.loc[df["genus"] == "Prosopis", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Potamogeton", "species_type"] = "aquatic"

df.loc[df["genus"] == "Pulsatilla", "species_type"] = "wildflower"

df.loc[df["genus"] == "Tropaeolum", "species_type"] = "wildflower"

df.loc[df["genus"] == "Pandanus", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Grindelia", "species_type"] = "wildflower"

df.loc[df["genus"] == "Ferula", "species_type"] = "wildflower"

df.loc[df["genus"] == "Symphyotrichum", "species_type"] = "wildflower"

# %%
df.loc[df["genus"] == "Drimia", "species_type"] = "wildflower"

df.loc[df["genus"] == "Hydrocotyle", "species_type"] = "aquatic"

df.loc[df["genus"] == "Lepidium", "species_type"] = "wildflower"

df.loc[df["genus"] == "Agathosma", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Zephyranthes", "species_type"] = "wildflower"

df.loc[df["genus"] == "Smilax", "species_type"] = "smilax"

df.loc[df["genus"] == "Verbascum", "species_type"] = "wildflower"

df.loc[df["genus"] == "Coprosma", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Genista", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Viburnum", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Celmisia", "species_type"] = "wildflower"

df.loc[df["genus"] == "Prostanthera", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Euphrasia", "species_type"] = "wildflower"

df.loc[df["genus"] == "Scrophularia", "species_type"] = "wildflower"

df.loc[df["genus"] == "Brickellia", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Terminalia", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Selago", "species_type"] = "wildflower"

df.loc[df["genus"] == "Lycium", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Myosotis", "species_type"] = "wildflower"

df.loc[df["genus"] == "Leucopogon", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Stellaria", "species_type"] = "wildflower"

df.loc[df["genus"] == "Fritillaria", "species_type"] = "wildflower"

df.loc[df["genus"] == "Erysimum", "species_type"] = "wildflower"

df.loc[df["genus"] == "Ceropegia", "species_type"] = "vine"

df.loc[df["genus"] == "Bidens", "species_type"] = "wildflower"

df.loc[df["genus"] == "Leptospermum", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Eugenia", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Erodium", "species_type"] = "wildflower"

df.loc[df["genus"] == "Pinguicula", "species_type"] = "wildflower"

df.loc[df["genus"] == "Antimima", "species_type"] = "succulent"

df.loc[df["genus"] == "Erythrina", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Gagea", "species_type"] = "wildflower"

df.loc[df["genus"] == "Hieracium", "species_type"] = "wildflower"

# %%
df.loc[df["genus"] == "Solidago", "species_type"] = "wildflower"

df.loc[df["genus"] == "Lilium", "species_type"] = "wildflower"

df.loc[df["genus"] == "Clinopodium", "species_type"] = "wildflower"

df.loc[df["genus"] == "Watsonia", "species_type"] = "wildflower"

df.loc[df["genus"] == "Leucadendron", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Cuscuta", "species_type"] = "vine"

df.loc[df["genus"] == "Micranthes", "species_type"] = "wildflower"

df.loc[df["genus"] == "Jamesbrittenia", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Ribes", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Aquilegia", "species_type"] = "wildflower"

df.loc[df["genus"] == "Daviesia", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Gaultheria", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Kniphofia", "species_type"] = "wildflower"

df.loc[df["genus"] == "Chenopodium", "species_type"] = "wildflower"

df.loc[df["genus"] == "Thalictrum", "species_type"] = "wildflower"

df.loc[df["genus"] == "Cynanchum", "species_type"] = "vine"

df.loc[df["genus"] == "Cissus", "species_type"] = "vine"

df.loc[df["genus"] == "Cotoneaster", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Buddleja", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Cordia", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Senegalia", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Arenaria", "species_type"] = "wildflower"

df.loc[df["genus"] == "Bauhinia", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Azorella", "species_type"] = "wildflower"

df.loc[df["genus"] == "Symplocos", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Polygonum", "species_type"] = "wildflower"

df.loc[df["genus"] == "Onobrychis", "species_type"] = "wildflower"

df.loc[df["genus"] == "Costus", "species_type"] = "wildflower"

df.loc[df["genus"] == "Ardisia", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Tragopogon", "species_type"] = "wildflower"

# %%
df.loc[df["genus"] == "Suillus", "species_type"] = "slippery jack"

df.loc[df["genus"] == "Helvella", "species_type"] = "elfin saddle"

df.loc[df["genus"] == "Morchella", "species_type"] = "morel"

df.loc[df["genus"] == "Hydnellum", "species_type"] = "tooth fungi"

# %%
df.loc[df["genus"] == "Lactifluus", "species_type"] = "milk cap"

df.loc[df["genus"] == "Phellinus", "species_type"] = "cork fungi"

df.loc[df["genus"] == "Scutellinia", "species_type"] = "cup fungi"

df.loc[df["genus"] == "Peniophora", "species_type"] = "crust fungi"

df.loc[df["genus"] == "Scleroderma", "species_type"] = "earth ball"

df.loc[df["genus"] == "Steccherinum", "species_type"] = "toothed crust fungi"

df.loc[df["genus"] == "Lentinellus", "species_type"] = "lamellate agaric"

df.loc[df["genus"] == "Chroogomphus", "species_type"] = "pine spike"

df.loc[df["genus"] == "Laetiporus", "species_type"] = "polypore"

df.loc[df["genus"] == "Clavariadelphus", "species_type"] = "club fungi"

df.loc[df["genus"] == "Phellodon", "species_type"] = "tooth fungi"

df.loc[df["genus"] == "Trichaptum", "species_type"] = "polypore"

df.loc[df["genus"] == "Artomyces", "species_type"] = "club fungi"

df.loc[df["genus"] == "Phaeoclavulina", "species_type"] = "club fungi"

df.loc[df["genus"] == "Calostoma", "species_type"] = "gasteroid"

df.loc[df["genus"] == "Austropaxillus", "species_type"] = "gill"

df.loc[df["genus"] == "Gomphidius", "species_type"] = "spike cap"

df.loc[df["genus"] == "Fuscoporia", "species_type"] = "polypore"

df.loc[df["genus"] == "Diatrype", "species_type"] = "crust fungi"

df.loc[df["genus"] == "Hericium", "species_type"] = "hericium"

df.loc[df["genus"] == "Chaenothecopsis", "species_type"] = "lichenized fungi"

df.loc[df["genus"] == "Claviceps", "species_type"] = "ergot"

df.loc[df["genus"] == "Xylodon", "species_type"] = "crust fungi"

df.loc[df["genus"] == "Rhytisma", "species_type"] = "tar spot"

df.loc[df["genus"] == "Annulohypoxylon", "species_type"] = "cramp ball"

df.loc[df["genus"] == "Sarcodon", "species_type"] = "tooth fungi"

df.loc[df["genus"] == "Rhizopogon", "species_type"] = "false truffle"

df.loc[df["genus"] == "Fomitopsis", "species_type"] = "polypore"

df.loc[df["genus"] == "Astraeus", "species_type"] = "earth star"

df.loc[df["genus"] == "Strigula", "species_type"] = "lichenized fungi"

# %%
df.loc[df["genus"] == "Linaria", "species_type"] = "wildflower"

df.loc[df["genus"] == "Cerastium", "species_type"] = "wildflower"

df.loc[df["genus"] == "Penstemon", "species_type"] = "wildflower"

df.loc[df["genus"] == "Romulea", "species_type"] = "wildflower"

df.loc[df["genus"] == "Phacelia", "species_type"] = "wildflower"

# %%
df.loc[df["genus"] == "Hakea", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Protea", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Epilobium", "species_type"] = "wildflower"

df.loc[df["genus"] == "Gentianella", "species_type"] = "wildflower"

df.loc[df["genus"] == "Geissorhiza", "species_type"] = "wildflower"

df.loc[df["genus"] == "Matelea", "species_type"] = "vine"

df.loc[df["genus"] == "Lotus", "species_type"] = "wildflower"

df.loc[df["genus"] == "Crataegus", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Crocus", "species_type"] = "wildflower"

df.loc[df["genus"] == "Orobanche", "species_type"] = "wildflower"

df.loc[df["genus"] == "Saussurea", "species_type"] = "wildflower"

df.loc[df["genus"] == "Vachellia", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Albuca", "species_type"] = "wildflower"

df.loc[df["genus"] == "Persicaria", "species_type"] = "wildflower"

df.loc[df["genus"] == "Mesembryanthemum", "species_type"] = "succulent"

df.loc[df["genus"] == "Drosanthemum", "species_type"] = "succulent"

df.loc[df["genus"] == "Ixia", "species_type"] = "wildflower"

df.loc[df["genus"] == "Pultenaea", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Papaver", "species_type"] = "wildflower"

df.loc[df["genus"] == "Psoralea", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Berkheya", "species_type"] = "wildflower"

df.loc[df["genus"] == "Ramaria", "species_type"] = "coral fungi"

df.loc[df["genus"] == "Searsia", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Eremophila", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Corydalis", "species_type"] = "wildflower"

df.loc[df["genus"] == "Sisyrinchium", "species_type"] = "wildflower"

df.loc[df["genus"] == "Syzygium", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Crepis", "species_type"] = "wildflower"

df.loc[df["genus"] == "Combretum", "species_type"] = "tree/shrub"

# %%
df.loc[df["genus"] == "Agave", "species_type"] = "agave"

df.loc[df["genus"] == "Limonium", "species_type"] = "wildflower"

df.loc[df["genus"] == "Valeriana", "species_type"] = "wildflower"

df.loc[df["genus"] == "Rosa", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Hermannia", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Hibbertia", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Linum", "species_type"] = "wildflower"

df.loc[df["genus"] == "Diospyros", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Asclepias", "species_type"] = "wildflower"

df.loc[df["genus"] == "Berberis", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Delosperma", "species_type"] = "succulent"

# %%
df.loc[df["genus"] == "Palicourea", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Gentiana", "species_type"] = "wildflower"

df.loc[df["genus"] == "Psychotria", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Thymus", "species_type"] = "wildflower"

df.loc[df["genus"] == "Babiana", "species_type"] = "wildflower"

df.loc[df["genus"] == "Prunus", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Erythranthe", "species_type"] = "wildflower"

df.loc[df["genus"] == "Convolvulus", "species_type"] = "vine"

df.loc[df["genus"] == "Muraltia", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Verbesina", "species_type"] = "wildflower"

df.loc[df["genus"] == "Draba", "species_type"] = "wildflower"

df.loc[df["genus"] == "Rumex", "species_type"] = "wildflower"

df.loc[df["genus"] == "Delphinium", "species_type"] = "wildflower"

df.loc[df["genus"] == "Lupinus", "species_type"] = "wildflower"

df.loc[df["genus"] == "Stylidium", "species_type"] = "wildflower"

df.loc[df["genus"] == "Eryngium", "species_type"] = "wildflower"

df.loc[df["genus"] == "Lampranthus", "species_type"] = "succulent"

df.loc[df["genus"] == "Ornithogalum", "species_type"] = "wildflower"

df.loc[df["genus"] == "Oenothera", "species_type"] = "wildflower"

df.loc[df["genus"] == "Cardamine", "species_type"] = "wildflower"

df.loc[df["genus"] == "Dioscorea", "species_type"] = "vine"

df.loc[df["genus"] == "Heliconia", "species_type"] = "wildflower"

df.loc[df["genus"] == "Boronia", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Echeveria", "species_type"] = "succulent"

df.loc[df["genus"] == "Taraxacum", "species_type"] = "wildflower"

df.loc[df["genus"] == "Colchicum", "species_type"] = "wildflower"

# %%
df.loc[df["genus"] == "Acacia", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Acer", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Achillea", "species_type"] = "wildflower"

df.loc[df["genus"] == "Aconitum", "species_type"] = "wildflower"

df.loc[df["genus"] == "Aeonium", "species_type"] = "succulent"

df.loc[df["genus"] == "Agalinis", "species_type"] = "wildflower"

df.loc[df["genus"] == "Iris", "species_type"] = "wildflower"

df.loc[df["genus"] == "Trifolium", "species_type"] = "wildflower"

df.loc[df["genus"] == "Cirsium", "species_type"] = "wildflower"

df.loc[df["genus"] == "Pedicularis", "species_type"] = "wildflower"

df.loc[df["genus"] == "Aloe", "species_type"] = "aloe"

df.loc[df["genus"] == "Oxytropis", "species_type"] = "wildflower"

df.loc[df["genus"] == "Geranium", "species_type"] = "wildflower"

df.loc[df["genus"] == "Campanula", "species_type"] = "wildflower"

df.loc[df["genus"] == "Crassula", "species_type"] = "succulent"

df.loc[df["genus"] == "Moraea", "species_type"] = "wildflower"

df.loc[df["genus"] == "Galium", "species_type"] = "wildflower"

df.loc[df["genus"] == "Drosera", "species_type"] = "wildflower"

df.loc[df["genus"] == "Quercus", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Sedum", "species_type"] = "succulent"

df.loc[df["genus"] == "Potentilla", "species_type"] = "wildflower"

df.loc[df["genus"] == "Gladiolus", "species_type"] = "wildflower"

df.loc[df["genus"] == "Centaurea", "species_type"] = "wildflower"

# %%
df.loc[df["genus"] == "Eucalyptus", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Begonia", "species_type"] = "wildflower"

df.loc[df["genus"] == "Silene", "species_type"] = "wildflower"

df.loc[df["genus"] == "Ranunculus", "species_type"] = "wildflower"

df.loc[df["genus"] == "Rubus", "species_type"] = "bramble"

df.loc[df["genus"] == "Oxalis", "species_type"] = "wildflower"

df.loc[df["genus"] == "Allium", "species_type"] = "wildflower"

df.loc[df["genus"] == "Acacia", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Erica", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Russula", "species_type"] = "russula"

df.loc[df["genus"] == "Aspalathus", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Lactarius", "species_type"] = "milkcap"

df.loc[df["genus"] == "Peperomia", "species_type"] = "wildflower"

df.loc[df["genus"] == "Miconia", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Primula", "species_type"] = "wildflower"

df.loc[df["genus"] == "Dianthus", "species_type"] = "wildflower"

df.loc[df["genus"] == "Melaleuca", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Anthurium", "species_type"] = "wildflower"

df.loc[df["genus"] == "Plantago", "species_type"] = "wildflower"

df.loc[df["genus"] == "Lachenalia", "species_type"] = "wildflower"

df.loc[df["genus"] == "Rhododendron", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Castilleja", "species_type"] = "wildflower"

df.loc[df["genus"] == "Ruschia", "species_type"] = "succulent"

df.loc[df["genus"] == "Saxifraga", "species_type"] = "wildflower"

df.loc[df["genus"] == "Grevillea", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Scutellaria", "species_type"] = "wildflower"

df.loc[df["genus"] == "Alchemilla", "species_type"] = "wildflower"

df.loc[df["genus"] == "Cliffortia", "species_type"] = "tree/shrub"

df.loc[df["genus"] == "Impatiens", "species_type"] = "wildflower"

df.loc[df["genus"] == "Clematis", "species_type"] = "vine"

df.loc[df["genus"] == "Erigeron", "species_type"] = "wildflower"

# %%
df.loc[df["scientific_name"] == "Garateia ximenae", "species_type"] = "arthropod"

df.loc[
    df["scientific_name"] == "Kuschelorhynchus macadamiae", "species_type"
] = "arthropod"

df.loc[df["scientific_name"] == "Baculomia siamensis", "species_type"] = "arthropod"

df.loc[df["scientific_name"] == "Xenocerogria ruficollis", "species_type"] = "arthropod"

df.loc[df["scientific_name"] == "Chorispora tenella", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Hardenbergia violacea", "species_type"] = "vine"

df.loc[df["scientific_name"] == "Anticlea elegans", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Sisymbrium irio", "species_type"] = "wildflower"

df.loc[
    df["scientific_name"] == "Chamaecytisus ruthenicus", "species_type"
] = "tree/shrub"

df.loc[df["scientific_name"] == "Leonotis nepetifolia", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Veronica spicata", "species_type"] = "wildflower"

df.loc[
    df["scientific_name"] == "Malvastrum coromandelianum", "species_type"
] = "wildflower"

df.loc[df["scientific_name"] == "Polygala lutea", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Euphorbia serpens", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Euphorbia bicolor", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Verbena officinalis", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Veronica beccabunga", "species_type"] = "succulent"

df.loc[df["scientific_name"] == "Condea emoryi", "species_type"] = "tree/shrub"

df.loc[df["scientific_name"] == "Euphorbia nutans", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Helleborus foetidus", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Passiflora suberosa", "species_type"] = "vine"

# %%
df.loc[df["scientific_name"] == "Cnidoscolus stimulosus", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Lonicera periclymenum", "species_type"] = "vine"

df.loc[df["scientific_name"] == "Mazus pumilus", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Taraxia ovata", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Petasites hybridus", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Echium plantagineum", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Euphorbia lathyris", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Melicytus ramiflorus", "species_type"] = "tree/shrub"

df.loc[df["scientific_name"] == "Hylotelephium telephium", "species_type"] = "succulent"

df.loc[df["scientific_name"] == "Dichondra carolinensis", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Malva parviflora", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Marah fabacea", "species_type"] = "vine"

df.loc[df["scientific_name"] == "Viscaria vulgaris", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Passiflora caerulea", "species_type"] = "vine"

df.loc[df["scientific_name"] == "Clintonia uniflora", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Eriobotrya japonica", "species_type"] = "tree/shrub"

df.loc[df["scientific_name"] == "Arctotheca calendula", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Alcea rosea", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Cardiospermum halicacabum", "species_type"] = "vine"

df.loc[df["scientific_name"] == "Veronica filiformis", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Ageratina adenophora", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Consolida regalis", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Umbilicus rupestris", "species_type"] = "succulent"

df.loc[df["scientific_name"] == "Armoracia rusticana", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Solanum dimidiatum", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Mitella diphylla", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Panax trifolius", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Scaevola taccada", "species_type"] = "tree/shrub"

df.loc[df["scientific_name"] == "Pueraria montana", "species_type"] = "vine"

df.loc[df["scientific_name"] == "Lindheimera texana", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Inula helenium", "species_type"] = "wildflower"

# %%
df.loc[df["scientific_name"] == "Deinandra fasciculata", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Marah oregana", "species_type"] = "vine"

df.loc[df["scientific_name"] == "Polanisia dodecandra", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Hibiscus trionum", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Pulicaria dysenterica", "species_type"] = "wildflower"

df.loc[
    df["scientific_name"] == "Euphorbia hypericifolia", "species_type"
] = "wildflower"

df.loc[df["scientific_name"] == "Odontites vulgaris", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Galinsoga parviflora", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Malva thuringiaca", "species_type"] = "tree/shrub"

df.loc[df["scientific_name"] == "Medicago arabica", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Hyoscyamus niger", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Tradescantia pallida", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Euphorbia polycarpa", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Verbena bonariensis", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Viola riviniana", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Brassica tournefortii", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Teucrium scorodonia", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Helichrysum arenarium", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Calotropis procera", "species_type"] = "tree/shrub"

df.loc[df["scientific_name"] == "Ipomoea hederacea", "species_type"] = "vine"

df.loc[df["scientific_name"] == "Sambucus ebulus", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Echium candicans", "species_type"] = "tree/shrub"

df.loc[df["scientific_name"] == "Fallopia convolvulus", "species_type"] = "vine"

df.loc[df["scientific_name"] == "Salvia rosmarinus", "species_type"] = "tree/shrub"

df.loc[df["scientific_name"] == "Adonis vernalis", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Acanthus mollis", "species_type"] = "wildflower"

df.loc[
    df["scientific_name"] == "Camissoniopsis cheiranthifolia", "species_type"
] = "wildflower"

# %%
df.loc[df["scientific_name"] == "Viola tricolor", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Croton setiger", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Glebionis coronaria", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Succisa pratensis", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Ipomoea indica", "species_type"] = "vine"

df.loc[
    df["scientific_name"] == "Tradescantia fluminensis", "species_type"
] = "wildflower"

df.loc[df["scientific_name"] == "Sisymbrium loeselii", "species_type"] = "wildflower"

df.loc[
    df["scientific_name"] == "Osteospermum moniliferum", "species_type"
] = "tree/shrub"

df.loc[df["scientific_name"] == "Jasione montana", "species_type"] = "wildflower"

df.loc[
    df["scientific_name"] == "Polygonatum multiflorum", "species_type"
] = "wildflower"

df.loc[df["scientific_name"] == "Solanum lycopersicum", "species_type"] = "vine"

df.loc[df["scientific_name"] == "Anthyllis vulneraria", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Euonymus verrucosus", "species_type"] = "tree/shrub"

df.loc[df["scientific_name"] == "Momordica charantia", "species_type"] = "vine"

df.loc[df["scientific_name"] == "Rapistrum rugosum", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Calandrinia menziesii", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Polygonatum odoratum", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Diodia virginiana", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Circaea canadensis", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Passiflora foetida", "species_type"] = "vine"

# %%
df.loc[df["scientific_name"] == "Thunbergia alata", "species_type"] = "vine"

df.loc[df["scientific_name"] == "Euphorbia marginata", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Lespedeza cuneata", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Sisymbrium officinale", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Lonicera tatarica", "species_type"] = "tree/shrub"

df.loc[df["scientific_name"] == "Trollius europaeus", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Solanum mauritianum", "species_type"] = "tree/shrub"

df.loc[df["scientific_name"] == "Centaurium erythraea", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Senecio inaequidens", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Ipomoea cairica", "species_type"] = "vine"

df.loc[
    df["scientific_name"] == "Toxicoscordion fremontii", "species_type"
] = "wildflower"

df.loc[df["scientific_name"] == "Pachysandra terminalis", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Pilea microphylla", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Phlomoides tuberosa", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Mimosa pudica", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Verbena brasiliensis", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Oncosiphon pilulifer", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Cordyline australis", "species_type"] = "tree/shrub"

df.loc[df["scientific_name"] == "Urena lobata", "species_type"] = "tree/shrub"

df.loc[df["scientific_name"] == "Urtica urens", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Pimpinella saxifraga", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Pentanema britannicum", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Sanguisorba minor", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Sinapis arvensis", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Lathyrus sylvestris", "species_type"] = "vine"

df.loc[df["scientific_name"] == "Lathyrus tuberosus", "species_type"] = "vine"

# %%
df.loc[df["scientific_name"] == "Lysimachia latifolia", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Cocculus carolinus", "species_type"] = "vine"

df.loc[df["scientific_name"] == "Lathyrus vernus", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Euphorbia virgata", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Viola arvensis", "species_type"] = "wildflower"

df.loc[
    df["scientific_name"] == "Sphagneticola trilobata", "species_type"
] = "wildflower"

df.loc[
    df["scientific_name"] == "Leonurus quinquelobatus", "species_type"
] = "wildflower"

df.loc[df["scientific_name"] == "Tridax procumbens", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Acmispon glaber", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Lonicera xylosteum", "species_type"] = "tree/shrub"

df.loc[df["scientific_name"] == "Perilla frutescens", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Viola odorata", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Hibiscus syriacus", "species_type"] = "tree/shrub"

df.loc[df["scientific_name"] == "Ruellia simplex", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Mirabilis jalapa", "species_type"] = "wildflower"

# %%
df.loc[df["scientific_name"] == "Asparagus officinalis", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Medicago falcata", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Solanum rostratum", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Heracleum sosnowskyi", "species_type"] = "wildflower"

df.loc[
    df["scientific_name"] == "Parthenium hysterophorus", "species_type"
] = "wildflower"

df.loc[df["scientific_name"] == "Abutilon theophrasti", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Marah macrocarpa", "species_type"] = "vine"

df.loc[df["scientific_name"] == "Veronica longifolia", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Cynoglossum officinale", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Euphorbia helioscopia", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Butomus umbellatus", "species_type"] = "aquatic"

df.loc[df["scientific_name"] == "Salvia pratensis", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Tribulus terrestris", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Euphorbia prostrata", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Malva moschata", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Mercurialis perennis", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Betonica officinalis", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Nasturtium officinale", "species_type"] = "aquatic"

df.loc[df["scientific_name"] == "Peritoma arborea", "species_type"] = "tree/shrub"

df.loc[df["scientific_name"] == "Euphorbia hirta", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Plumbago auriculata", "species_type"] = "vine"

df.loc[
    df["scientific_name"] == "Sanguisorba officinalis", "species_type"
] = "wildflower"

df.loc[df["scientific_name"] == "Melilotus indicus", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Ballota nigra", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Lysimachia punctata", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Veronica hederifolia", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Malva neglecta", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Medicago polymorpha", "species_type"] = "wildflower"

df.loc[
    df["scientific_name"] == "Scorzoneroides autumnalis", "species_type"
] = "wildflower"

# %%
df.loc[df["scientific_name"] == "Alliaria petiolata", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Artemisia vulgaris", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Solanum dulcamara", "species_type"] = "vine"

df.loc[df["scientific_name"] == "Veronica persica", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Melilotus albus", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Vinca minor", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Lonicera japonica", "species_type"] = "vine"

df.loc[df["scientific_name"] == "Lysimachia arvensis", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Veronica chamaedrys", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Echium vulgare", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Medicago lupulina", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Securigera varia", "species_type"] = "vine"

df.loc[df["scientific_name"] == "Digitalis purpurea", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Vicia cracca", "species_type"] = "vine"

df.loc[df["scientific_name"] == "Hypericum perforatum", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Lonicera maackii", "species_type"] = "tree/shrub"

df.loc[df["scientific_name"] == "Senecio vulgaris", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Hesperis matronalis", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Celastrus orbiculatus", "species_type"] = "vine"

df.loc[df["scientific_name"] == "Anemonoides nemorosa", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Convallaria majalis", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Lantana camara", "species_type"] = "tree/shrub"

df.loc[df["scientific_name"] == "Vinca major", "species_type"] = "vine"

df.loc[df["scientific_name"] == "Ambrosia trifida", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Melilotus officinalis", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Ilex aquifolium", "species_type"] = "tree/shrub"

df.loc[df["scientific_name"] == "Vicia sativa", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Lactuca serriola", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Solanum elaeagnifolium", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Berteroa incana", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Foeniculum vulgare", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Jacobaea vulgaris", "species_type"] = "wildflower"

df.loc[
    df["scientific_name"] == "Tripleurospermum inodorum", "species_type"
] = "wildflower"

df.loc[df["scientific_name"] == "Ampelopsis glandulosa", "species_type"] = "vine"

df.loc[df["scientific_name"] == "Solanum carolinense", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Nicotiana glauca", "species_type"] = "tree/shrub"

df.loc[df["scientific_name"] == "Cymbalaria muralis", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Lunaria annua", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Euonymus alatus", "species_type"] = "tree/shrub"

df.loc[df["scientific_name"] == "Lysimachia nummularia", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Medicago sativa", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Leonurus cardiaca", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Vicia villosa", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Knautia arvensis", "species_type"] = "wildflower"

# %%
df.loc[df["scientific_name"] == "Lapsana communis",
       "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Sambucus cerulea",
       "species_type"] = "tree/shrub"

df.loc[df["scientific_name"] == "Sambucus canadensis",
       "species_type"] = "tree/shrub"

df.loc[df["scientific_name"] == "Lysimachia vulgaris",
       "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Lathyrus latifolius", "species_type"] = "vine"

df.loc[df["scientific_name"] == "Pastinaca sativa",
       "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Veronica serpyllifolia",
       "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Marrubium vulgare",
       "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Vicia sepium", "species_type"] = "vine"

df.loc[df["scientific_name"] == "Triadica sebifera",
       "species_type"] = "tree/shrub"

df.loc[df["scientific_name"] == "Malva sylvestris",
       "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Solanum nigrum", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Conopholis americana",
       "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Lathyrus pratensis", "species_type"] = "vine"

df.loc[df["scientific_name"] == "Veronica arvensis",
       "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Euonymus fortunei", "species_type"] = "vine"

df.loc[df["scientific_name"] == "Mycelis muralis", "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Euphorbia peplus",
       "species_type"] = "wildflower"

df.loc[
    df["scientific_name"] == "Galinsoga quadriradiata", "species_type"
] = "wildflower"

df.loc[df["scientific_name"] == "Euphorbia cyparissias",
       "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Artemisia absinthium",
       "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Euonymus europaeus",
       "species_type"] = "tree/shrub"

df.loc[
    df["scientific_name"] == "Helminthotheca echioides", "species_type"
] = "wildflower"

df.loc[df["scientific_name"] == "Eupatorium cannabinum",
       "species_type"] = "wildflower"

df.loc[df["scientific_name"] == "Cakile maritima", "species_type"] = "succulent"

df.loc[df["scientific_name"] == "Ficus carica", "species_type"] = "tree/shrub"

df.loc[df["scientific_name"] == "Stachys sylvatica",
       "species_type"] = "wildflower"

df.loc[
    df["scientific_name"] == "Anemonoides quinquefolia", "species_type"
] = "wildflower"

df.loc[df["scientific_name"] == "Ipomoea purpurea", "species_type"] = "vine"

df.loc[
    df["scientific_name"] == "Anemonoides ranunculoides", "species_type"
] = "wildflower"

df.loc[df["scientific_name"] == "Paragylla calida", "species_type"] = "insect"

# %%
na_animal["genus"].value_counts().head(30)

# %%
df["species_type"].replace(
    [
        "gill",
        "russula",
        "gill like",
        "milkcap",
        "milk cap",
        "spike cap",
        "lamellate agaric",
        "agaric",
        "pine spike",
    ],
    "gill_fungi",
    inplace=True,
)

df["species_type"].replace(
    [
        "earthstar",
        "earth star",
        "earth ball",
        "false truffle",
        "stinkhorn",
        "gasteroid",
    ],
    "gasteroid_fungi",
    inplace=True,
)

df["species_type"].replace(
    [
        "club fungi",
        "cup fungi",
        "polypore",
        "cork fungi",
        "tooth fungi",
        "bolete",
        "jelly fungi",
        "leathery earthfan",
        "earth tongue",
        "earth tongue like",
        "coral fungi",
        "elfin saddle",
        "hericium",
        "cramp ball",
        "morel",
        "slippery jack",
        "crust fungi",
        "toothed crust fungi",
    ],
    "non_gilled_fungi",
    inplace=True,
)

df["species_type"].replace(
    [
        "lichenized fungi",
        "lichenized club fungi",
        "rust fungi",
        "green and blue mold",
        "pin mold",
        "smut fungi",
        "tar spot",
        "budding yeast",
        "ergot",
    ],
    "other_fungi",
    inplace=True,
)

# %%
df["species_type"].replace(
    ["tree/shrub", "gnetophyte", "cycad", "bramble", "grasstree"],
    "tree_shrub",
    inplace=True,
)

df["species_type"].replace(
    [
        "smilax",
    ],
    "vine",
    inplace=True,
)

df["species_type"].replace(
    ["aquatic", "cactus", "succulent", "aloe", "agave"], "water_master", inplace=True
)

df["species_type"].replace(["orchid"], "wildflower", inplace=True)

df["species_type"].replace(
    ["moss", "fern", "liverwort", "lycopod", "hornwort", "fern ally"],
    "other_plants",
    inplace=True,
)

df["species_type"].replace(
    [
        "brown algae",
        "algae",
        "heterokont algae",
        "golden brown algae",
        "red algae",
        "green algae",
        "diatom",
        "dinoflagellate",
    ],
    "algae",
    inplace=True,
)

# %%
df["species_type"].replace(
    [
        "centipede",
        "fish lice",
        "fairy shrimp",
        "dipluran",
        "springtail",
        "insect",
        "arachnid",
        "millipede",
        "malacostracan",
        "barnacle",
        "water flea",
        "plankton",
        "sea spider",
        "tadpole shrimp",
        "ostracod",
        "horseshoe crab",
    ],
    "arthropod",
    inplace=True,
)

df["species_type"].replace(
    ["cartilaginous fish", "ray fin fish", "hagfish", "lamprey", "lobe fin fish"],
    "fish",
    inplace=True,
)

df["species_type"].replace(
    ["jellyfish", "coral/anemone", "hydrozoan"], "cnidaria", inplace=True
)

df["species_type"].replace(
    ["cephalopod", "slug/snail", "chiton", "bivalve", "tusk shell", "solenogaster"],
    "mollusk",
    inplace=True,
)

df["species_type"].replace(
    ["ascidian", "larvacean", "salp"], "tunicate", inplace=True)

df["species_type"].replace(
    [
        "round worm",
        "velvet worm",
        "flat worm",
        "echinoderm",
        "ribbon worm",
        "nematode",
        "tardigrade",
        "arrow worm",
        "rotifer",
        "hairy belly",
        "horsehair worm",
        "acorn worm",
        "peanut worm",
        "xenacoelomorph",
    ],
    "worm",
    inplace=True,
)

df["species_type"].replace(
    ["sponge", "bryozoa", "brachiopod", "comb jelly", "horseshoe worm", "tunicate"],
    "other_animals",
    inplace=True,
)

# %%
df.loc[
    (df["kingdom"] == "Fungi") & (df["species_type"].isna()), "species_type"
] = "uncategorized_fungi"

df.loc[
    (df["kingdom"] == "Plantae") & (df["species_type"].isna()), "species_type"
] = "uncategorized_plants"

# %%
# remove "<NA>" values from unique_id column in df

# df['unique_id'].apply(lambda x: print(x) if ('<NA>' in x) else x)

df["unique_id"] = df["unique_id"].apply(
    lambda x: x[x != "<NA>"] if ("<NA>" in x) else x
)

# %%
df["unique_id"].apply(lambda x: print(x) if ("<NA>" in x) else x)

# %%
# na_common = df[(df["common_name"].isna())]

# %%
# na_common

# %%
df

# %%
df_merge_path = input("Enter the file path: ")

# write df to parquet file using pandas to_parquet
df.to_parquet(df_merge_path)
